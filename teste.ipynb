# %%
import pandas as pd

# %%
with open(r'C:\Users\mrsilva\Documents\sap_estudos\ETL_SAP_PROJECT\FI\CustomerTexts.csv', 'r') as file:
    df_customer_texts = pd.read_csv(file, sep = ',', encoding='utf-8')

df_customer_texts.head(5)
# Out:
#   CUSTOMERID LANGUAGE  SHORT_DESCR    MEDIUM_DESCR  LONG_DESCR
# 0          #       EN          NaN      Unassigned         NaN
# 1   LACU_S02       EN          NaN       TechCycle         NaN
# 2    1000153       EN          NaN  Suburban Cycle         NaN
# 3   LACU_S03       EN          NaN   All for Bikes         NaN
# 4   LACU_S04       EN          NaN         Bike On         NaN

# %%
df_customer_texts['LONG_DESCR'].unique()
# Out:
# array([nan])

# %%
with open(r'C:\Users\mrsilva\Documents\sap_estudos\ETL_SAP_PROJECT\FI\GLAccountsTexts.csv', 'r') as file:
    df_gl_accounts_texts = pd.read_csv(file, sep = ',', encoding='utf-8')

df_gl_accounts_texts.head(5)
# Out:
#   ACCOUNTID LANGUAGE  SHORT_DESCR                               MEDIUM_DESCR  \
# 0    CF_CFO       EN          NaN  Cash Flow from Operating Activities (CFO)
# 1      CF_D       EN          NaN                               Depreciation
# 2      CF_I       EN          NaN             Cash Flow Statement (indirect)
# 3  FPA1/020       EN          NaN                         Cost of Goods Sold
# 4  FPA1/022       EN          NaN                              Gross Revenue
#
#    LONG_DESCR
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df_gl_accounts_texts['SHORT_DESCR'].unique()
df_gl_accounts_texts['LONG_DESCR'].unique()
# Out:
# array([nan])

# %%
with open(r'C:\Users\mrsilva\Documents\sap_estudos\ETL_SAP_PROJECT\FI\ProductCategoryTexts.csv', 'r') as file:
    df_product_category_texts = pd.read_csv(file, sep = ',', encoding='utf-8')

# %%
df_product_category_texts.head(5)
# Out:
#   PRODCATEGORYID LANGUAGE     SHORT_DESCR  MEDIUM_DESCR  LONG_DESCR
# 0             FG       EN  Finished Goods           NaN         NaN
# 1             CR       EN          Cruise           NaN         NaN
# 2             MT       EN        Mountain           NaN         NaN
# 3             RB       EN    Racing Bikes           NaN         NaN
# 4             RC       EN          Racing           NaN         NaN

# %%
df_product_category_texts['SHORT_DESCR'].unique()
df_product_category_texts['LONG_DESCR'].unique()
# Out:
# array([nan])

# %%
with open(r'C:\Users\mrsilva\Documents\sap_estudos\ETL_SAP_PROJECT\FI\ProductTexts.csv', 'r') as file:
    df_product_texts = pd.read_csv(file, sep = ',', encoding='utf-8')

df_product_texts.head(5)
# Out:
#    PRODUCTID LANGUAGE SHORT_DESCR        MEDIUM_DESCR  LONG_DESCR
# 0  CM-FL-V00       EN    Forklift            Forklift         NaN
# 1      FG226       EN      FG 226  Finished Goods 226         NaN
# 2       M-01       EN   Bike M-01           Bike M-01         NaN
# 3         M1       EN     Bike M1             Bike M1         NaN
# 4  MZ-FG-C10       EN    Bike C10            Bike C10         NaN

# %%
df_product_texts['LONG_DESCR'].unique()
# Out:
# array([nan])

# %%
with open (r'C:\Users\mrsilva\Documents\sap_estudos\ETL_SAP_PROJECT\Sales\SalesOrderItems.csv', 'r') as file:
    df_sales_order_items = pd.read_csv(file, sep = ';', encoding='utf-8')

df_sales_order_items.head(5)
# Out:
#    ï»¿SALESORDERID  SALESORDERITEM   PRODUCTID  NOTEID CURRENCY  GROSSAMOUNT  \
# 0        200000000              10  MZ-FG-R100     NaN      USD         4999
# 1        200000001              10  MZ-FG-P010     NaN      USD         1199
# 2        200000002              10  MZ-FG-E102     NaN      USD          399
# 3        200000003              10   MZ-FG-E15     NaN      USD         3999
# 4        200000003              20  MZ-FG-C990     NaN      USD          721
#
#   NETAMOUNT TAXAMOUNT ITEMATPSTATUS  OPITEMPOS  QUANTITY QUANTITYUNIT  \
# 0   4374,13    624,88             I        NaN         6           EA
# 1   1049,13    149,88             I        NaN         3           EA
# 2    349,13     49,88             I        NaN         7           EA
# 3   3499,13    499,88             I        NaN         5           EA
# 4    630,88     90,13             I        NaN         9           EA
#
#    DELIVERYDATE
# 0      20150226
# 1      20150215
# 2      20150308
# ...

# %%
df_sales_order_items['DELIVERYDATE'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 17818 entries, 0 to 17817
# Series name: DELIVERYDATE
# Non-Null Count  Dtype
# --------------  -----
# 17818 non-null  int64
# dtypes: int64(1)
# memory usage: 139.3 KB

# %%
with open(r'C:\Users\mrsilva\Documents\sap_estudos\ETL_SAP_PROJECT\Sales\BusinessPartners.csv', 'r') as file:
    df_business_partners = pd.read_csv(file, sep = ';', encoding='utf-8')

df_business_partners.head(5)
# Out:
#    PARTNERID  PARTNERROLE                      EMAILADDRESS  PHONENUMBER  \
# 0  100000000            2         maria.brown@all4bikes.com    622734567
# 1  100000001            2          bob.buyer@amazebikes.com      3088530
# 2  100000002            2  victor.sanchez@arenasportusa.com   3023352668
# 3  100000003            2     franklin.jones@atlantausa.com    511403266
# 4  100000004            2       robert_brown@bikeworlds.com   2244668800
#
#    FAXNUMBER                    WEBADDRESS   ADDRESSID       COMPANYNAME  \
# 0        NaN      http://www.all4bikes.com  1000000034     All For Bikes
# 1        NaN     http://www.amazebikes.com  1000000035   Amaze Bikes Inc
# 2        NaN  http://www.arenasportusa.com  1000000036  Arena Sports Inc
# 3        NaN     http://www.atlantausa.com  1000000037  Atlanta Corp Inc
# 4        NaN     http://www.bikeworlds.com  1000000038    Bike World Inc
#
#   LEGALFORM  CREATEDBY   CREATEDAT  CHANGEDBY   CHANGEDAT CURRENCY
# ...

# %%
df_business_partners['CREATEDAT'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40 entries, 0 to 39
# Series name: CREATEDAT
# Non-Null Count  Dtype
# --------------  -----
# 40 non-null     object
# dtypes: object(1)
# memory usage: 452.0+ bytes

# %%
df_business_partners['CREATEDAT'] = pd.to_datetime(df_business_partners['CREATEDAT'], format='%Y-%m-%d', errors='coerce')

# %%
df_business_partners['CREATEDAT'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40 entries, 0 to 39
# Series name: CREATEDAT
# Non-Null Count  Dtype
# --------------  -----
# 40 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 452.0 bytes

# %%
df_business_partners.head(5)
# Out:
#    PARTNERID  PARTNERROLE                      EMAILADDRESS  PHONENUMBER  \
# 0  100000000            2         maria.brown@all4bikes.com    622734567
# 1  100000001            2          bob.buyer@amazebikes.com      3088530
# 2  100000002            2  victor.sanchez@arenasportusa.com   3023352668
# 3  100000003            2     franklin.jones@atlantausa.com    511403266
# 4  100000004            2       robert_brown@bikeworlds.com   2244668800
#
#    FAXNUMBER                    WEBADDRESS   ADDRESSID       COMPANYNAME  \
# 0        NaN      http://www.all4bikes.com  1000000034     All For Bikes
# 1        NaN     http://www.amazebikes.com  1000000035   Amaze Bikes Inc
# 2        NaN  http://www.arenasportusa.com  1000000036  Arena Sports Inc
# 3        NaN     http://www.atlantausa.com  1000000037  Atlanta Corp Inc
# 4        NaN     http://www.bikeworlds.com  1000000038    Bike World Inc
#
#   LEGALFORM  CREATEDBY  CREATEDAT  CHANGEDBY   CHANGEDAT CURRENCY
# ...
